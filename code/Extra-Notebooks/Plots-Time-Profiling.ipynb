# %%
import matplotlib.pyplot as plt
import numpy as np

# Resolutions for Geohash, H3, and S2 with their respective times
resolutions_geohash = np.arange(1, 13, 1)
times_geohash = [
    1.1173231999999995, 1.2743561000000003, 1.3938959000000004, 1.5236157999999982, 
    1.6808785000000057, 1.798695500000001, 2.0669401999999977, 2.144557799999994, 
    2.3218432999999976, 2.6197793000000047, 2.684356600000001, 2.727978399999998
]

resolutions_h3 = np.arange(0, 16, 1)
times_h3 = [
    1.1107743, 1.1972983999999993, 1.2010910999999993, 1.0672787000000028, 1.1549004999999966, 
    1.2388434999999944, 1.1713961000000026, 1.2400968999999975, 1.1805559000000017, 1.2212456999999972, 
    1.2708508000000052, 1.2452566999999988, 1.265428099999994, 1.204380999999998, 1.2080057999999951, 
    1.2246365000000026
]

resolutions_s2 = np.arange(0, 31, 1)
times_s2 = [
    2.6304806999999997, 2.633965700000001, 2.726541400000002, 2.603172800000003, 2.6577735000000047, 
    2.7251027999999877, 2.6204728000000017, 2.6698628999999983, 2.6140569000000085, 2.6215368999999953, 
    2.8047254999999893, 2.703861499999988, 2.6640597999999898, 2.680981800000012, 2.6362168999999938, 
    2.671588100000008, 2.6428834000000165, 2.6226058999999964, 2.657598500000006, 2.6510204999999587, 
    2.64366050000001, 3.0033141000000114, 3.0431422999999995, 2.82547679999999, 2.8180755000000204, 
    2.9333804999999984, 2.9674978999999553, 2.799377600000014, 2.7563553999999613, 2.6967875999999933, 
    2.7416687999999567
]

# Create plots for each geocoding technique separately
plt.figure(figsize=(18, 6))

# Geohash
plt.subplot(1, 3, 1)
plt.plot(resolutions_geohash, times_geohash, marker='o', color='blue')
plt.title('Geohash: Time vs. Precision')
plt.xlabel('Geohash Precision')
plt.ylabel('Time (seconds)')
plt.grid(True)

# H3
plt.subplot(1, 3, 2)
plt.plot(resolutions_h3, times_h3, marker='s', color='green')
plt.title('H3: Time vs. Resolution')
plt.xlabel('H3 Resolution')
plt.grid(True)

# S2
plt.subplot(1, 3, 3)
plt.plot(resolutions_s2, times_s2, marker='^', color='red')
plt.title('S2: Time vs. Resolution')
plt.xlabel('S2 Resolution')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample fractions
fractions = np.arange(0.1, 1.1, 0.1)

# Times in seconds for each geocoding technique
times_geohash = [0.291, 0.584, 0.887, 1.157, 1.481, 1.776, 2.100, 2.351, 2.672, 2.972]
times_h3 = [0.160, 0.324, 0.481, 0.643, 0.813, 0.977, 1.139, 1.321, 1.478, 1.623]
times_s2 = [0.393, 0.792, 1.172, 1.568, 1.966, 2.371, 2.781, 3.141, 3.536, 3.981]

plt.figure(figsize=(10, 6))
plt.plot(fractions, times_geohash, label='Geohash', marker='o')
plt.plot(fractions, times_h3, label='H3', marker='s')
plt.plot(fractions, times_s2, label='S2', marker='^')
plt.title('Time Profiling: Fixed Geocode Resolution and Varying Dataset Size')
plt.xlabel('Sampling Fraction')
plt.ylabel('Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Resolutions for Geohash, H3, and S2 with their respective times
resolutions_geohash = np.arange(1, 13, 1)
times_geohash = [
    1.1173231999999995, 1.2743561000000003, 1.3938959000000004, 1.5236157999999982, 
    1.6808785000000057, 1.798695500000001, 2.0669401999999977, 2.144557799999994, 
    2.3218432999999976, 2.6197793000000047, 2.684356600000001, 2.727978399999998
]

resolutions_h3 = np.arange(0, 16, 1)
times_h3 = [
    1.1107743, 1.1972983999999993, 1.2010910999999993, 1.0672787000000028, 1.1549004999999966, 
    1.2388434999999944, 1.1713961000000026, 1.2400968999999975, 1.1805559000000017, 1.2212456999999972, 
    1.2708508000000052, 1.2452566999999988, 1.265428099999994, 1.204380999999998, 1.2080057999999951, 
    1.2246365000000026
]

resolutions_s2 = np.arange(0, 31, 1)
times_s2 = [
    2.6304806999999997, 2.633965700000001, 2.726541400000002, 2.603172800000003, 2.6577735000000047, 
    2.7251027999999877, 2.6204728000000017, 2.6698628999999983, 2.6140569000000085, 2.6215368999999953, 
    2.8047254999999893, 2.703861499999988, 2.6640597999999898, 2.680981800000012, 2.6362168999999938, 
    2.671588100000008, 2.6428834000000165, 2.6226058999999964, 2.657598500000006, 2.6510204999999587, 
    2.64366050000001, 3.0033141000000114, 3.0431422999999995, 2.82547679999999, 2.8180755000000204, 
    2.9333804999999984, 2.9674978999999553, 2.799377600000014, 2.7563553999999613, 2.6967875999999933, 
    2.7416687999999567
]

# Determine the global y-axis limits for uniformity in all plots
global_ymin = min(min(times_geohash), min(times_h3), min(times_s2))
global_ymax = max(max(times_geohash), max(times_h3), max(times_s2))

# Plot Geohash
plt.figure(figsize=(6, 4))
plt.plot(resolutions_geohash, times_geohash, marker='o', color='blue')
plt.title('Geohash: Time vs. Precision')
plt.xlabel('Geohash Precision')
plt.ylabel('Time (seconds)')
plt.ylim(global_ymin, global_ymax)
plt.grid(True)
plt.show()

# Plot H3
plt.figure(figsize=(6, 4))
plt.plot(resolutions_h3, times_h3, marker='s', color='green')
plt.title('H3: Time vs. Resolution')
plt.xlabel('H3 Resolution')
plt.ylabel('Time (seconds)')
plt.ylim(global_ymin, global_ymax)
plt.grid(True)
plt.show()

# Plot S2
plt.figure(figsize=(6, 4))
plt.plot(resolutions_s2, times_s2, marker='^', color='red')
plt.title('S2: Time vs. Resolution')
plt.xlabel('S2 Resolution')
plt.ylabel('Time (seconds)')
plt.ylim(global_ymin, global_ymax)
plt.grid(True)
plt.show()

# %%
# Normalize and rescale the x-values to match the range of S2
# Geohash original range [1, 12], normalize and scale to [0, 30]
norm_resolutions_geohash = (resolutions_geohash - 1) / (12 - 1) * 30

# H3 original range [0, 15], normalize and scale to [0, 30]
norm_resolutions_h3 = resolutions_h3 / 15 * 30

# S2 is already on a [0, 30] scale, no change needed
norm_resolutions_s2 = resolutions_s2

# Plotting all three datasets on the same figure
plt.figure(figsize=(10, 6))
plt.plot(norm_resolutions_geohash, times_geohash, marker='o', color='blue', label='Geohash')
plt.plot(norm_resolutions_h3, times_h3, marker='s', color='green', label='H3')
plt.plot(norm_resolutions_s2, times_s2, marker='^', color='red', label='S2')
plt.title('Comparison of Geocoding Techniques: Time vs. Normalized Resolution')
plt.xlabel('Normalized Resolution')  # Will hide this later
plt.ylabel('Time (seconds)')
plt.ylim(global_ymin, global_ymax)
plt.legend()
plt.grid(True)
plt.xticks([])  # Hiding x-axis labels
plt.show()
