# %%
import matplotlib.pyplot as plt
import numpy as np

# Resolutions for Geohash, H3, and S2
resolutions_geohash = np.arange(1, 13, 1)
resolutions_h3 = np.arange(0, 16, 1)
resolutions_s2 = np.arange(0, 31, 1)

# Normalize and rescale the x-values to match the range of S2
# Geohash original range [1, 12], normalize and scale to [0, 30]
norm_resolutions_geohash = (resolutions_geohash - 1) / (12 - 1) * 30
# H3 original range [0, 15], normalize and scale to [0, 30]
norm_resolutions_h3 = resolutions_h3 / 15 * 30
# S2 is already on a [0, 30] scale, no change needed
norm_resolutions_s2 = resolutions_s2

# Sampling fractions (Neighborhood Approximation)
fractions_ne = np.linspace(0.1, 1.0, 10)
# Sampling fractions (Stratified Sampling)
fractions_ss = np.linspace(0.1, 0.9, 9)

# %%
# RMSE data
rmse_geohash = [0.7872242112127358,
 0.6942867293848732,
 0.3583648170008069,
 0.2863192423606081,
 0.2330986857163828,
 0.20707311105977133,
 0.21521537121575743,
 0.12213574740952547,
 0.08231127274371541,
 1.7404859584931204e-15]
rmse_h3 = [0.5470520608443175,
 0.407649561079405,
 0.3243836408386735,
 0.3661316702146308,
 0.2619994399438814,
 0.2599788691464143,
 0.19483577221599424,
 0.14352310122417092,
 0.10221902107680512,
 1.7404859584931204e-15]
rmse_s2 = [0.6576977593057721,
 0.5535049499942194,
 0.45433104780829353,
 0.25357386651614705,
 0.30807251349893855,
 0.23688851517266615,
 0.18352972475796195,
 0.1471335669254128,
 0.07208710208284344,
 1.7404859584931204e-15]

# MAPE data
mape_geohash = [1.6015593840546576,
 1.0043489542614188,
 1.3124359768996345,
 0.6333260332378056,
 0.6548193099472039,
 0.4811538170467665,
 0.6132643160848038,
 0.33342367099572784,
 0.2063228706274301,
 3.356156612226708e-15]
mape_h3 = [1.9213676597823859,
 1.6904173577924275,
 1.0868879819182367,
 0.8178528188374717,
 0.7841129715995003,
 0.628276950884683,
 0.47401473003729144,
 0.4272861181357803,
 0.30539757561822284,
 3.356156612226708e-15]
mape_s2 = [1.7610554344175817,
 1.4804810572646128,
 0.869422584069436,
 0.906903211692619,
 0.9760391665330421,
 0.8396455301252228,
 0.3579728925199787,
 0.4199962107810736,
 0.1496166863574953,
 3.356156612226708e-15]

# Plotting RMSE comparison
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(fractions_ne, rmse_geohash, label='Geohash', marker='o')
plt.plot(fractions_ne, rmse_h3, label='H3', marker='^')
plt.plot(fractions_ne, rmse_s2, label='S2', marker='s')
plt.title('RMSE Comparison Across Sampling Fractions')
plt.xlabel('Sampling Fraction')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True)

# Plotting MAPE comparison
plt.subplot(1, 2, 2)
plt.plot(fractions_ne, mape_geohash, label='Geohash', marker='o')
plt.plot(fractions_ne, mape_h3, label='H3', marker='^')
plt.plot(fractions_ne, mape_s2, label='S2', marker='s')
plt.title('MAPE Comparison Across Sampling Fractions')
plt.xlabel('Sampling Fraction')
plt.ylabel('MAPE (%)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# RMSE data
rmse_geohash = [2.7588272532912135,
 2.757812268251215,
 2.757599435422668,
 2.428514536040869,
 0.8025258995054997,
 0.17386641789504956,
 0.23152861033583977,
 0.259762848788751,
 0.30477537904284496,
 0.2545032904415007,
 0.23919532591088416,
 0.27210971429807645]
rmse_h3 = [2.7596307793191923,
 2.7616516926832366,
 2.7596143566649,
 2.4471583089288185,
 2.7198119204161952,
 2.5932494134309603,
 1.4651269369975906,
 0.2497556426203755,
 0.25645270138722126,
 0.24056978082640473,
 0.18043370520806068,
 0.23046777777352034,
 0.2615985065497944,
 0.23284708742159854,
 0.2467774291592885,
 0.13833006656946298]
rmse_s2 = [2.7594525238753618,
 2.759227269454606,
 2.7619538252811733,
 2.7592853351684457,
 2.7561418798145705,
 2.763476373118116,
 2.7579330906064112,
 2.757588513088155,
 2.513355245563924,
 2.4113234839461137,
 1.7820145856527398,
 0.4784922344350549,
 0.25466245881284183,
 0.23463212414834583,
 0.16689062122967183,
 0.2053887774297547,
 0.27463646915900175,
 0.17300741675959352,
 0.21246308457177554,
 0.15407119695376545,
 0.19263039882574462,
 0.24329639059400715,
 0.16173435962240576,
 0.25597215735326745,
 0.1418987750718378,
 0.3334401286298748,
 0.1885184237636821,
 0.26691048911019283,
 0.28848329607571804,
 0.19185379147834244,
 0.21934243586587696]

# MAPE data
mape_geohash = [8.515136464085531,
 8.447288734161653,
 8.521851095839454,
 7.851790019559028,
 2.223141718389456,
 0.5896718926445871,
 0.8223289971612667,
 0.39721010820113944,
 0.6589239511034789,
 0.6284680831495846,
 0.591770002570065,
 0.690125758430309]
mape_h3 = [8.520882670764628,
 8.412635516196506,
 8.456718541383776,
 7.745854173918361,
 8.39009043392015,
 8.213819501219149,
 3.6145157179149927,
 0.6444526649464561,
 0.5732774930175144,
 0.6929286633547685,
 0.6552139593638475,
 0.7863022112218484,
 0.4327100633208911,
 0.4096599880958703,
 0.7253136238718494,
 0.43793747848628006]
mape_s2 = [8.557772009113755,
 8.428592015434019,
 8.45888555757535,
 8.486922456771744,
 8.4899003902019,
 8.486498210564934,
 8.446749501104252,
 8.497206727411575,
 7.790784620291593,
 7.538607871999742,
 5.082545107160719,
 1.2388439855401014,
 0.621574498844371,
 0.762129805511217,
 0.6281834374230922,
 0.8076497997206871,
 0.5315354455991971,
 0.6417444899175065,
 0.4242520685835462,
 0.6016419337913748,
 0.6021109924503286,
 0.5671306868729463,
 0.43369473634849737,
 0.6550403115531227,
 0.4376836098929109,
 0.43495896085379865,
 0.6199634731579448,
 0.5172284441393686,
 0.7705850131845253,
 0.5169848340863951,
 0.6403241766566666]

# %%
# Combine plots for each type
def plot_combined_data(resolutions, rmse_data, mape_data, color, title_prefix, resolution_phrase='Resolution'):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    ax1.plot(resolutions, rmse_data, 'o-', color=color)
    ax1.set_title(f'{title_prefix} RMSE vs. {resolution_phrase}')
    ax1.set_xlabel(resolution_phrase)
    ax1.set_ylabel('RMSE')
    ax1.grid(True)
    
    ax2.plot(resolutions, mape_data, 'o-', color=color)
    ax2.set_title(f'{title_prefix} MAPE vs. {resolution_phrase}')
    ax2.set_xlabel(resolution_phrase)
    ax2.set_ylabel('MAPE (%)')
    ax2.grid(True)
    
    plt.tight_layout()
    plt.show()

# Plotting
plot_combined_data(resolutions_geohash, rmse_geohash, mape_geohash, 'blue', 'Geohash', 'Precision')
plot_combined_data(resolutions_h3, rmse_h3, mape_h3, 'green', 'H3')
plot_combined_data(resolutions_s2, rmse_s2, mape_s2, 'red', 'S2')

# %%
# Determine the global y-axis limits
global_ymin_rmse = min(min(rmse_geohash), min(rmse_h3), min(rmse_s2))
global_ymax_rmse = max(max(rmse_geohash), max(rmse_h3), max(rmse_s2))

# Adjust y-axis minimum to be at most 0
global_ymin_rmse = min(global_ymin_rmse, 0)

# Adjust y-axis maximum to be one step higher; determine step by analyzing the data spread
rmse_range = global_ymax_rmse - global_ymin_rmse
y_step_rmse = rmse_range / 10  # Example step calculation, dividing into ten parts
global_ymax_rmse += y_step_rmse

# Determine the global y-axis limits for uniformity in all plots
global_ymin_mape = min(min(min(mape_geohash), min(mape_h3), min(mape_s2)), 0)
global_ymax_mape = max(max(mape_geohash), max(mape_h3), max(mape_s2)) + 5

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Plot RMSE
ax1.plot(norm_resolutions_geohash, rmse_geohash, 'o-', color='blue', label='Geohash')
ax1.plot(norm_resolutions_h3, rmse_h3, 's-', color='green', label='H3')
ax1.plot(norm_resolutions_s2, rmse_s2, '^-', color='red', label='S2')
ax1.set_title('Overlayed Comparison: RMSE vs. Normalized Resolution')
ax1.set_xlabel('Normalized Resolution')
ax1.set_ylabel('RMSE')
ax1.set_ylim(global_ymin_rmse, global_ymax_rmse)
ax1.legend()
ax1.grid(True)
ax1.set_xticks([])  # Hiding x-axis labels

# Plot MAPE
ax2.plot(norm_resolutions_geohash, mape_geohash, 'o-', color='blue', label='Geohash')
ax2.plot(norm_resolutions_h3, mape_h3, 's-', color='green', label='H3')
ax2.plot(norm_resolutions_s2, mape_s2, '^-', color='red', label='S2')
ax2.set_title('Overlayed Comparison: MAPE vs. Normalized Resolution')
ax2.set_xlabel('Normalized Resolution')
ax2.set_ylabel('MAPE (%)')
ax2.set_ylim(global_ymin_mape, global_ymax_mape)
ax2.legend()
ax2.grid(True)
ax2.set_xticks([])  # Hiding x-axis labels

plt.tight_layout()
plt.show()

# %%
# RMSE data for each geocoding technique from Test B, Subtest 1
rmse_geohash = [0.5708799256345652, 0.40833395910344433, 0.3308341117056014, 0.2662336204079625, 0.2619263346768185, 0.22159610476791994, 0.14208771977948978, 0.11480341809435957, 0.06875112720046184]
rmse_h3 = [0.6068433705229694, 0.3919806446421442, 0.29645844521337583, 0.24462359683890236, 0.23990225017584335, 0.179710418497285, 0.15884897405707019, 0.10227020101263332, 0.071698313673488]
rmse_s2 = [0.5741727051802104, 0.421305584193146, 0.33926221971601644, 0.12055464992897967, 0.2250427274961128, 0.22450653965459547, 0.14129782259538634, 0.09986196247203363, 0.059631241297709955]

# Plotting RMSE comparison for Test B, Subtest 1
plt.figure(figsize=(10, 6))
plt.plot(fractions_ss, rmse_geohash, label='Geohash', marker='o')
plt.plot(fractions_ss, rmse_h3, label='H3', marker='s')
plt.plot(fractions_ss, rmse_s2, label='S2', marker='^')
plt.title('RMSE Comparison Across Sampling Fractions')
plt.xlabel('Sampling Fraction')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True)
plt.show()

# %%
# RMSE data
rmse_geohash = [0.19717281862438024, 0.20776808034899016, 0.1216060347667172, 0.1836499817045044, 0.1594524322286488, 0.14336242213700737, 0.15896174896926712, 0.1564022388520964, 0.16359853230110022, 0.18273700986865238, 0.17974199301708943, 0.2351266144495695]
rmse_h3 = [0.1841293292209716, 0.19174933450500925, 0.17020005679543163, 0.19044926219643626, 0.2027815552138217, 0.16755092303647484, 0.18273807792865682, 0.15645260125362048, 0.11962826129448195, 0.17588118213184462, 0.17953528666658775, 0.15162984675754448, 0.14138883232892618, 0.14185226925596708, 0.20021794695425196, 0.1814458889425828]
rmse_s2 = [0.11854184349235676, 0.1610039380568493, 0.18702426521489238, 0.1902559040013145, 0.1279060562829423, 0.1837062784035046, 0.17246020767769354, 0.19630879979723048, 0.15909697239472156, 0.18507742477185923, 0.182811173561169, 0.15115796326610334, 0.18395080901927507, 0.1676968974366973, 0.18272551747187152, 0.16310546388508895, 0.1605315593276196, 0.18245457011820632, 0.1582394692966537, 0.14500145454888833, 0.19075626030375478, 0.17217206838082252, 0.15790097148095075, 0.17716859041426092, 0.1786819277619529, 0.162679741204157, 0.17962209840075477, 0.15877012741041732, 0.17583499316650833, 0.16170151563830504, 0.22121437551519757]

# %%
# Plots for each type
def plot_data(resolutions, rmse_data, color, title_prefix, resolution_phrase='Resolution'):
    plt.figure(figsize=(6, 4))
    plt.plot(resolutions, rmse_data, 'o-', color=color)
    plt.title(f'{title_prefix} RMSE vs. {resolution_phrase}')
    plt.xlabel(resolution_phrase)
    plt.ylabel('RMSE')
    plt.grid(True)
    plt.show()

# Plotting
plot_data(resolutions_geohash, rmse_geohash, 'blue', 'Geohash', 'Precision')
plot_data(resolutions_h3, rmse_h3, 'green', 'H3')
plot_data(resolutions_s2, rmse_s2, 'red', 'S2')

# %%
# Determine the global y-axis limits
global_ymin_rmse = min(min(rmse_geohash), min(rmse_h3), min(rmse_s2))
global_ymax_rmse = max(max(rmse_geohash), max(rmse_h3), max(rmse_s2))

# Adjust y-axis minimum to be at most 0
global_ymin_rmse = min(global_ymin_rmse, 0)

# Adjust y-axis maximum to be one step higher; determine step by analyzing the data spread
rmse_range = global_ymax_rmse - global_ymin_rmse
y_step_rmse = rmse_range / 10  # Example step calculation, dividing into ten parts
global_ymax_rmse += y_step_rmse

plt.figure(figsize=(10, 6))
plt.plot(norm_resolutions_geohash, rmse_geohash, 'o-', color='blue', label='Geohash')
plt.plot(norm_resolutions_h3, rmse_h3, 's-', color='green', label='H3')
plt.plot(norm_resolutions_s2, rmse_s2, '^-', color='red', label='S2')
plt.title('Overlayed Comparison: RMSE vs. Normalized Resolution')
plt.xlabel('Normalized Resolution')
plt.ylabel('RMSE')
plt.ylim(global_ymin_rmse, global_ymax_rmse)
plt.legend()
plt.grid(True)
plt.xticks([])  # Hiding x-axis labels
plt.show()
